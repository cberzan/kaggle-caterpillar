# %%
import pandas as pd

pd.set_option('display.max_columns', None)

# %%
# 100 trees:
# df = pd.read_csv('opt/hyperopt-2015-08-26T14:15:39.704429.csv')

# 1000 trees:
df = pd.read_csv('ec2/hyperopt-2015-08-27T01:32:24.393333.csv')

len(df)
# Out:
# 200

# %%
df.sort('loss', inplace=True)
df[:10]
# Out:
#      colsample_bytree   eta                 finish_time  gamma      loss  \
# 155               0.6  0.02  2015-08-27T10:23:50.581279    0.0  0.216727
# 152               0.6  0.03  2015-08-27T10:09:52.757867    0.0  0.216787
# 146               0.6  0.03  2015-08-27T09:42:15.661067    0.0  0.216838
# 68                0.6  0.03  2015-08-27T05:03:36.318441    0.0  0.216905
# 69                0.6  0.03  2015-08-27T05:08:24.500592    0.0  0.216905
# 96                0.6  0.04  2015-08-27T06:49:49.960948    0.0  0.217025
# 156               0.6  0.02  2015-08-27T10:28:48.216917    0.1  0.217507
# 94                0.5  0.03  2015-08-27T06:41:32.095181    0.0  0.217664
# 153               0.5  0.03  2015-08-27T10:14:00.739789    0.1  0.217741
# 116               0.6  0.02  2015-08-27T07:53:29.838685    0.0  0.218058
#
#      loss_variance  max_depth  min_child_weight  num_rounds   objective  \
# 155       0.000186         20                18        1000  reg:linear
# 152       0.000181         17                15        1000  reg:linear
# 146       0.000168         18                15        1000  reg:linear
# 68        0.000208         19                13        1000  reg:linear
# 69        0.000208         19                13        1000  reg:linear
# 96        0.000206         13                13        1000  reg:linear
# 156       0.000194         20                18        1000  reg:linear
# 94        0.000193         18                13        1000  reg:linear
# 153       0.000194         19                20        1000  reg:linear
# 116       0.000225         15                11        1000  reg:linear
#
#      silent status  subsample  test_rmsle_avg  test_rmsle_std  \
# 155       1     ok        0.8        0.216727        0.013627
# 152       1     ok        0.8        0.216787        0.013469
# 146       1     ok        0.8        0.216838        0.012980
# 68        1     ok        0.5        0.216905        0.014407
# 69        1     ok        0.5        0.216905        0.014407
# 96        1     ok        0.8        0.217025        0.014363
# 156       1     ok        0.8        0.217507        0.013928
# 94        1     ok        0.8        0.217664        0.013885
# 153       1     ok        0.8        0.217741        0.013920
# 116       1     ok        0.5        0.218058        0.015013
#
#      test_wall_time_avg  test_wall_time_std  train_rmsle_avg  train_rmsle_std  \
# 155            0.130519            0.011778         0.070265         0.000735
# 152            0.110305            0.005467         0.057522         0.000639
# 146            0.123701            0.014032         0.054080         0.000661
# 68             0.121060            0.003793         0.061740         0.000739
# 69             0.123109            0.009062         0.061740         0.000739
# 96             0.087514            0.006610         0.062606         0.000696
# 156            0.111421            0.005647         0.085598         0.000451
# 94             0.121610            0.009232         0.050797         0.000950
# 153            0.096864            0.002981         0.082138         0.000453
# 116            0.104784            0.013806         0.087256         0.000905
#
#      train_wall_time_avg  train_wall_time_std
# 155            29.059517             0.144029
# 152            25.438890             0.616696
# 146            26.551884             0.111604
# 68             28.507689             0.179812
# 69             28.160584             0.360379
# 96             23.504611            11.043503
# 156            29.115863             0.230740
# 94             23.499171             0.187998
# 153            24.165253             0.265307
# 116            23.401706             0.146127

# %%
subset = df[:20]

# %%
subset.max_depth.value_counts()
# Out:
# 20    4
# 18    4
# 17    4
# 19    3
# 15    2
# 14    1
# 13    1
# 16    1
# dtype: int64

# %%
# Out:
# 200
